# %% [markdown]
# # EXERCISE 4.10 (A)
# # Coding Etiquette & Excel Reporting

# %% [markdown]
# #### Table of Content
#
# 1. Importing Libraries
# 2. Dataframe
# 3. Checking the Dataframe
# 4. Following Exercise 4.10

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Dataframe

# %%
path = r'/Users/charliegehant/Dropbox/4. Career Foundry/Achievement 4 - Python Fundamentals for Data Analysts/02-2022 Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/charliegehant/Dropbox/4. Career Foundry/Achievement 4 - Python Fundamentals for Data Analysts/02-2022 Instacart Basket Analysis'

# %%
# Importing dataframe 'orders.csv'

df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'))

# %% [markdown]
# ## 3. Checking the Dataframe

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.shape
# Out:
# (3421083, 7)

# %% [markdown]
# ## 4. Following Exercise 4.10

# %%
# Crosstab = a sort of Pivot Table, but for Python!

crosstab = pd.crosstab(df['days_since_prior_order'], df['order_number'], dropna = False)

# %%
# Copy/Paste the crosstabs result to clipboard, ready to be pasted in Excel

crosstab.to_clipboard()

# %%
# Printing the crosstab here for reference

crosstab
# Out:
# order_number            1      2      3      4      5      6      7      8    \
# days_since_prior_order
# 0.0                       0   2899   2915   2964   2634   2443   2236   2101
# 1.0                       0   4822   4613   4690   4423   4047   4000   3744
# 2.0                       0   6203   6209   6231   5789   5679   5274   5090
# 3.0                       0   7411   7577   7414   7097   6770   6424   6078
# 4.0                       0   8415   8476   8469   8029   7608   7092   6735
# 5.0                       0   9216   9329   9220   8600   8228   7703   7270
# 6.0                       0  11419  11701  11601  10771  10054   9521   8842
# 7.0                       0  16788  16609  16341  15135  13834  13268  12452
# 8.0                       0  10422  10304  10148   9378   8738   8068   7594
# 9.0                       0   7053   7160   7013   6610   5993   5497   5082
# 10.0                      0   5969   6037   5938   5376   5018   4479   4245
# ...

# %%
# Checking the data

df[['order_number', 'days_since_prior_order']].max()
# Out:
# order_number              100.0
# days_since_prior_order     30.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')
